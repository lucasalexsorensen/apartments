# %%
import numpy as np
import matplotlib.pyplot as plt

# asking price of Prinsessegade 2B, 4. 91
price = 3_600_000 / 51

# %%
# scraped from boliga
#   type: ejerlejlighed
#   sal: >= 1
prices = {
    'christianshavn': np.array([61857,58481,65346,68750,98618,74360,77160,68425,73113,92583,74742,86153,54807,61363,60826,62727,74193,68607,77464,75247,69257,69013]),
    'indreby': np.array([81712,58894,79268,76696,62403,48241,55909,76923,76892,53928,78918,83582,64902,74257,68687,63492,61461,67361,72327,66609,68908,73709,106458,86185,51702,48148,69794,67387,55042,41107,66929,59356,67287,78815,82568,66600,58333,64214,55235,62945,71369,65094,98684,71164,68355,40609,48739,49920,54806,60862,50266,70093,49683,65789,54597,52458,62952,57295,57347,60191,60661,49504,52301,46508,89887,59013,73913,91463,74503,68750,38971,40563,53991,61845,65517,79439,81325,85460,72080,71309,70921,65745,48349,65346,64718,61315,66139,50479,64957,59177,51239,77827,57584,59937,68705,65990,60696,57336,85714,44975,64612,78535,112500,79338,75424,56842,64193,64102,68804,90136,72113,59177,68464,68604,63895,60126,70387,67089,134693,45075,54224,55921,115000,81036,63926,64766,70243,71969,71931,70274,57336,59941,65163,58010,57897,60530,74763,80252,96534])
}

# %% [markdown]
# ### Indre by
# <img width=300 height=300 src="indreby.jpg" />

# %%
percentile = np.sum(prices['indreby'] < price) / len(prices['indreby'])
plt.title(f'Indre by\nn={len(prices["indreby"])} opslag\nPercentile: {percentile:.2%}')
plt.hist(prices['indreby'], bins=20)
plt.vlines(price, 0, 30, color='r', lw=5, label='Prinsessegade 2B, 4. 91')
plt.legend()
plt.show()

# %% [markdown]
# ### Christianshavn
# <img width=300 height=300 src="christianshavn.jpg" />

# %%
percentile = np.sum(prices['christianshavn'] < price) / len(prices['christianshavn'])
plt.title(f'Indre by\nn={len(prices["christianshavn"])} opslag\nPercentile: {percentile:.2%}')
plt.hist(prices['christianshavn'], bins=20)
plt.vlines(price, 0, 8, color='r', lw=5, label='Prinsessegade 2B, 4. 91')
plt.legend()
plt.show()
